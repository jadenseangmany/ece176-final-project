# %% [markdown]
# # Short-term stock market prediction with Time Series Transformer Network

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torch.optim as optim

from sklearn.model_selection import train_test_split

import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
USE_GPU = True
device=None
dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

print('using device:', device)
# print(torch.cuda.device_count())
# print(torch.cuda.get_device_name(0))
# Out:
# using device: mps

# %%
## Only run this once if merged_stock.csv does not exist. (takes 2 minutes to run)

# folder_path = 'datasets/2021'
# all_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# merged_df = pd.concat([pd.read_csv(os.path.join(folder_path, file)).assign(stock=file[:-4]) for file in all_files])

## Save the merged dataset
# merged_df.to_csv("merged_stocks.csv", index=False)
# merged_df.head()

# data_all = pd.read_csv("datasets/Kaggle_Dow_Jones_30_Historical_Data.csv")
# data_all.replace('?', 0, inplace=True)
# data_all.replace(np.nan, 0, inplace=True)

# %%
stock_df = pd.read_csv('merged_stocks.csv')
stock_df.head()
# Out:
#   ticker                                              name  \
# 0    RIV  RiverNorth Opportunities Fund, Inc. Common Stock
# 1    RIV  RiverNorth Opportunities Fund, Inc. Common Stock
# 2    RIV  RiverNorth Opportunities Fund, Inc. Common Stock
# 3    RIV  RiverNorth Opportunities Fund, Inc. Common Stock
# 4    RIV  RiverNorth Opportunities Fund, Inc. Common Stock
#
#                         date       open       high        low      close  \
# 0  2021-01-04 09:30:00-05:00  16.200001  16.200600  15.900000  15.959000
# 1  2021-01-04 10:30:00-05:00  15.950000  16.090000  15.950000  16.040001
# 2  2021-01-04 11:30:00-05:00  16.046101  16.125000  16.002100  16.080000
# 3  2021-01-04 12:30:00-05:00  16.020000  16.129999  15.980000  16.129999
# 4  2021-01-04 13:30:00-05:00  16.129999  16.299999  16.129999  16.219999
#
#    adjusted close   volume stock
# 0       15.959000      0.0   RIV
# 1       16.040001  25335.0   RIV
# 2       16.080000  14404.0   RIV
# 3       16.129999  14389.0   RIV
# 4       16.219999  11725.0   RIV

# %%
# Check how many nans there are 
missing_values = (stock_df.isna().sum() / len(stock_df)) * 100
print(missing_values)
# stock_df.dropna(inplace=True)
# stock_df.isnull().any()

#data_all.isnull().values.any()

#data_all.isnull().any() #check for any NaN

#nan_rows = data_all[data_all['Walmart'].isnull()]
#data_all.columns

#DEBUG
#nans = test_data.isin([nan])
# Out:
# ticker            0.000000
# name              0.000000
# date              0.000000
# open              0.003708
# high              0.003708
# low               0.003708
# close             0.003708
# adjusted close    0.003708
# volume            0.003708
# stock             0.000000
# dtype: float64

# %%
# We see that there are less than a percent of nans, so we can drop them all
stock_df.dropna(inplace=True)

# %%
#...
# Out:
# /var/folders/gh/j69cmlrs3ys39tqrjt2ww_hm0000gn/T/ipykernel_97759/1529601679.py:4: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   stock_df['date'] = pd.to_datetime(stock_df['date'], errors='coerce')
# ticker             object
# name               object
# date               object
# open              float64
# high              float64
# low               float64
# close             float64
# adjusted close    float64
# volume            float64
# stock              object
# dtype: object

# %%
print(stock_df.dtypes)
# Out:
# ticker             object
# name               object
# date               object
# open              float64
# high              float64
# low               float64
# close             float64
# adjusted close    float64
# volume            float64
# stock              object
# dtype: object

# %%
# Normalize numeric features
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
stock_df[['open', 'high', 'low', 'close', 'adjusted close', 'volume']] = scaler.fit_transform(stock_df[['open', 'high', 'low', 'close', 'adjusted close', 'volume']])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

# Set hyperparameters
window_length = 12
pred_length = 6  # Make length even to keep things simpler
batch_size = 1024

# Split into train and test datasets
split = 5700
train_data = stock_df.iloc[:split, :]
test_data = stock_df.iloc[split:, :]

def preprocess(data, window_length=window_length, pred_length=pred_length):
    # Keep only numeric columns (avoid ticker/name causing errors)
    numeric_columns = ["open", "high", "low", "close", "adjusted close", "volume"]
    data = data[numeric_columns].melt()["value"]

    # Convert to numeric, handling missing values
    data = pd.to_numeric(data, errors="coerce").fillna(method="ffill").to_numpy()  # Fill missing values

    # Normalize based on entire dataset (not per-window)
    data_min, data_max = np.min(data), np.max(data)
    data = (data - data_min) / (data_max - data_min + 1e-8)

    time_length = data.size
    x, y = [], []

    # Sequential slicing instead of random offsets
    for window_index in range(0, time_length - window_length - pred_length, window_length):
        window = data[window_index:window_index + window_length]
        
        x.append(window[:pred_length])  # First part as input
        y.append(window[pred_length:])  # Second part as target

    x, y = np.asarray(x), np.asarray(y)

    # Reshape for transformers (batch_size, seq_length, num_features)
    x = np.reshape(x, [x.shape[0], x.shape[1], 1])
    y = np.reshape(y, [y.shape[0], y.shape[1], 1])

    # Apply positional encoding to ALL sequences
    dim_model = 1
    max_len = pred_length
    position_encoding = np.zeros([max_len, dim_model], dtype=np.float32)
    position_list = np.reshape(np.arange(0, max_len, dtype=np.float32), [-1, 1])
    denominator = np.exp(-np.log(10000.0) * np.arange(0, dim_model, 2, dtype=np.float32)/dim_model)
    position_encoding[:, 0::2] = np.sin(position_list / denominator)
    position_encoding[:, 1::2] = np.cos(position_list / denominator)

    # Apply encoding to ALL sequences, not just x[0]
    for i in range(x.shape[0]):
        x[i, :, 0] = position_encoding[:, 0]
        y[i, :, 0] = position_encoding[:, 0]

    return x, y

# Process training and test datasets
x_train, y_train = preprocess(train_data)
x_test, y_test = preprocess(test_data)

# Create DataLoaders
train_loader = DataLoader(list(zip(x_train, y_train)), batch_size=batch_size, shuffle=True)
test_loader = DataLoader(list(zip(x_test, y_test)), batch_size=batch_size, shuffle=False)  # Keep shuffle=False for testing


# PREVIOUS CODE IS BELOW HERE

# window_length=12 
# pred_length=6 #make len even to keep things simpler
# batch_size = 1024#512 #too big?

# #split into train and test datasets
# split = 5700
# train_data = stock_df.iloc[:split, :]
# test_data = stock_df.iloc[split:, :] 

# def preprocess(data, window_length = window_length, pred_length = pred_length):
#     #flatten all stocks into one column  
#     data = data.iloc[:, 1:].melt()
#     data = data.iloc[:, 1]
    
#     data = pd.to_numeric(data).to_numpy() #faster to do slicing operation as numpy array than pandas
#     time_length = data.size

#     #split into sections of length window_length, normalize, then put first half in x and second half in y
#     x = [] 
#     y = []
#     for window_index in np.arange( np.random.randint(0,window_length-1), time_length-window_length-pred_length, window_length):  
#         window = np.array(data[window_index:window_index+window_length])
#         window = window-np.min(window) 
#         window = window/np.max(window)

#         x.append(window[0:pred_length])
#         y.append(window[pred_length:window_length])
     
#     x = np.asarray(x)
#     y = np.asarray(y)

#     #add positional enccoding
#     x = np.reshape(x, [x.shape[0], x.shape[1], 1])#reshape into N, S, E where S is the source sequence length, T is the target sequence length, N is the batch size, EE is the feature number
#     y = np.reshape(y, [y.shape[0], y.shape[1], 1]) 

#     dim_model = 1 #number of features
#     max_len = pred_length 

#     position_encoding = np.zeros([max_len, dim_model], dtype=np.float32)
#     position_list = np.reshape(np.arange(0, max_len, dtype=np.float32), [-1, 1])
#     denominator = np.exp(-np.log(10000.0) * np.arange(0, dim_model, 2, dtype=np.float32)/dim_model) 
#     position_encoding[:, 0::2] = np.sin(position_list / denominator)
#     position_encoding[:, 1::2] = np.cos(position_list / denominator)

#     plt.imshow(position_encoding)
#     plt.figure()

#     x[0, :, 0] = position_encoding[:, 0] #replace 2nd dim with positional encodings
#     y[0, :, 0] = position_encoding[:, 0]
    
#     return x, y


# x_train, y_train = preprocess(train_data)
# x_test, y_test = preprocess(test_data)

# # print(x_train.shape)
# # print(y_train.shape)
# # print(x_train.dtype)

# train_loader = DataLoader(list(zip(x_train, y_train)), batch_size, shuffle=True) #x is same as y for simple scalar transformers, right?
# test_loader = DataLoader(list(zip(x_test, y_test)), batch_size, shuffle=True)
# Out:
# /var/folders/gh/j69cmlrs3ys39tqrjt2ww_hm0000gn/T/ipykernel_97759/2362083995.py:22: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = pd.to_numeric(data, errors="coerce").fillna(method="ffill").to_numpy()  # Fill missing values
# /var/folders/gh/j69cmlrs3ys39tqrjt2ww_hm0000gn/T/ipykernel_97759/2362083995.py:22: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = pd.to_numeric(data, errors="coerce").fillna(method="ffill").to_numpy()  # Fill missing values

# %%
print(x_test.shape)
print(x_test[:, 0, :])
# Out:
# (7508108, 6, 1)
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
# window_size = 16
# forecast_length = 16
# num_val = 2

# data_all['date'] = pd.to_datetime(data_all['date']) #convert int to datetime
# val_max_date = '2017-08-15'
# train_max_date = str((pd.to_datetime(val_max_date) - pd.Timedelta(days=window_size*num_val+forecast_length)).date())

# train_final = data_all[data_all['date']<=train_max_date]
# val_final = data_all[(data_all['date']>train_max_date)&(data_all['date']<=val_max_date)]

# train_series = train_final.groupby(categorical_static).agg(list).reset_index()
# val_series = val_final.groupby(categorical_static).agg(list).reset_index()

# #try changing date to ints
# train_series
# data_all['date'] = pd.to_datetime(data_all['date']) #convert int to datetime

# %%
# def divide_shuffle(df,div_num):
#     space = df.shape[0]//div_num
#     division = np.arange(0,df.shape[0],space)
#     return pd.concat([df.iloc[division[i]:division[i]+space,:].sample(frac=1) for i in range(len(division))])

# def create_time_blocks(time_length,window_size,forecast_length):
#     start_idx = np.random.randint(0,window_size-1)
#     end_idx = time_length-window_size-forecast_length-1
#     time_indices = np.arange(start_idx,end_idx+1,window_size)[:-1]
#     time_indices = np.append(time_indices,end_idx)
#     return time_indices

# def data_loader(x_numeric_tensor, x_category_tensor, x_static_tensor, y_tensor, batch_size, time_shuffle):

#     num_series = x_numeric_tensor.shape[0]
#     time_length = x_numeric_tensor.shape[1]
#     index_pd = pd.DataFrame({'serie_idx':range(num_series)})
#     index_pd['time_idx'] = [create_time_blocks(time_length,window_size,forecast_length) for n in range(index_pd.shape[0])]
#     if time_shuffle:
#         index_pd = index_pd.explode('time_idx')
#         index_pd = index_pd.sample(frac=1)
#     else:
#         index_pd = index_pd.explode('time_idx').sort_values('time_idx')
#         index_pd = divide_shuffle(index_pd,5)
#     indices = np.array(index_pd).astype(int)

#     for batch_idx in np.arange(0,indices.shape[0],batch_size):

#         cur_indices = indices[batch_idx:batch_idx+batch_size,:]

#         x_numeric = torch.stack([x_numeric_tensor[n[0],n[1]:n[1]+window_size,:] for n in cur_indices])
#         x_category = torch.stack([x_category_tensor[n[0],n[1]:n[1]+window_size,:] for n in cur_indices])
#         x_static = torch.stack([x_static_tensor[n[0],:] for n in cur_indices])
#         y = torch.stack([y_tensor[n[0],n[1]+window_size:n[1]+window_size+forecast_length] for n in cur_indices])

#         yield x_numeric.to(device), x_category.to(device), x_static.to(device), y.to(device)

# def val_loader(x_numeric_tensor, x_category_tensor, x_static_tensor, y_tensor, batch_size, num_val):

#     num_time_series = x_numeric_tensor.shape[0]

#     for i in range(num_val):

#       for batch_idx in np.arange(0,num_time_series,batch_size):

#           x_numeric = x_numeric_tensor[batch_idx:batch_idx+batch_size,window_size*i:window_size*(i+1),:]
#           x_category = x_category_tensor[batch_idx:batch_idx+batch_size,window_size*i:window_size*(i+1),:]
#           x_static = x_static_tensor[batch_idx:batch_idx+batch_size]
#           y_val = y_tensor[batch_idx:batch_idx+batch_size,window_size*(i+1):window_size*(i+1)+forecast_length]

#           yield x_numeric.to(device), x_category.to(device), x_static.to(device), y_val.to(device)

# %%
# #medium model
# #don't need to run this block
# class transformer_block(nn.Module):

#     def __init__(self,embed_size,num_heads):
#         super(transformer_block, self).__init__()

#         self.attention = nn.MultiheadAttention(embed_size, num_heads, batch_first=True)
#         self.fc = nn.Sequential(nn.Linear(embed_size, 4 * embed_size),
#                                  nn.LeakyReLU(),
#                                  nn.Linear(4 * embed_size, embed_size))
#         self.dropout = nn.Dropout(drop_prob)
#         self.ln1 = nn.LayerNorm(embed_size, eps=1e-6)
#         self.ln2 = nn.LayerNorm(embed_size, eps=1e-6)

#     def forward(self, x):

#         attn_out, _ = self.attention(x, x, x, need_weights=False)
#         x = x + self.dropout(attn_out)
#         x = self.ln1(x)

#         fc_out = self.fc(x)
#         x = x + self.dropout(fc_out)
#         x = self.ln2(x)

#         return x


# class transformer_forecaster(nn.Module):

#     def __init__(self,embed_size,num_heads,num_blocks):
#         super(transformer_forecaster, self).__init__()

#         num_len = len(numeric_covariates)
#         self.embedding_cov = nn.ModuleList([nn.Embedding(n,embed_size-num_len) for n in categorical_covariates_num_embeddings])
#         self.embedding_static = nn.ModuleList([nn.Embedding(n,embed_size-num_len) for n in categorical_static_num_embeddings])

#         self.blocks = nn.ModuleList([transformer_block(embed_size,num_heads) for n in range(num_blocks)])

#         self.forecast_head = nn.Sequential(nn.Linear(embed_size, embed_size*2),
#                                            nn.LeakyReLU(),
#                                            nn.Dropout(drop_prob),
#                                            nn.Linear(embed_size*2, embed_size*4),
#                                            nn.LeakyReLU(),
#                                            nn.Linear(embed_size*4, forecast_length),
#                                            nn.ReLU())

#     def forward(self, x_numeric, x_category, x_static):

#         tmp_list = []
#         for i,embed_layer in enumerate(self.embedding_static):
#             tmp_list.append(embed_layer(x_static[:,i]))
#         categroical_static_embeddings = torch.stack(tmp_list).mean(dim=0).unsqueeze(1)

#         tmp_list = []
#         for i,embed_layer in enumerate(self.embedding_cov):
#             tmp_list.append(embed_layer(x_category[:,:,i]))
#         categroical_covariates_embeddings = torch.stack(tmp_list).mean(dim=0)
#         T = categroical_covariates_embeddings.shape[1]

#         embed_out = (categroical_covariates_embeddings + categroical_static_embeddings.repeat(1,T,1))/2
#         x = torch.concat((x_numeric,embed_out),dim=-1)

#         for block in self.blocks:
#             x = block(x)

#         x = x.mean(dim=1)
#         x = self.forecast_head(x)

#         return x
    



# class RMSLELoss(nn.Module):

#     def __init__(self):
#         super().__init__()
#         self.mse = nn.MSELoss()

#     def forward(self, pred, actual):
#         return torch.sqrt(self.mse(torch.log(pred + 1), torch.log(actual + 1)))

# %%
class MyTransformerWrapper(nn.Module):
    def __init__(self, d_model=32, nhead=1, num_encoder_layers=6, num_decoder_layers=6):
        super().__init__()
        
        self.input_projection = nn.Linear(1, d_model)
        self.transformer = nn.Transformer(
            d_model=d_model,
            nhead=nhead,
            num_encoder_layers=num_encoder_layers,
            num_decoder_layers=num_decoder_layers,
            batch_first=True
        )
        self.output_projection = nn.Linear(d_model, 1)

    def forward(self, src, tgt, src_mask=None, tgt_mask=None,
                src_is_causal=False, tgt_is_causal=False):
        
        src_emb = self.input_projection(src)  # shape: (B, S, 1) -> (B, S, d_model)
        tgt_emb = self.input_projection(tgt)  # shape: (B, T, 1) -> (B, T, d_model)

        transformer_out = self.transformer(
            src_emb, 
            tgt_emb,
            src_mask=src_mask, 
            tgt_mask=tgt_mask,
            src_is_causal=src_is_causal,
            tgt_is_causal=tgt_is_causal
        )  # shape: (B, T, d_model)

        out = self.output_projection(transformer_out)  # shape: (B, T, d_model) -> (B, T, 1)
        return out

# %%
#Pytorch vanilla transformer with MSE loss

# transformer_model = nn.Transformer(d_model = 1, nhead=1, num_encoder_layers=6, num_decoder_layers=6, batch_first=True, device=device) #only 1 head bc of 1 input dimension
# src = torch.rand((batch_size, window_length, 1)).to(device=device, dtype=dtype)#10, 32, 512)) #replace w ...
# tgt = torch.rand((batch_size, pred_length, 1)).to(device=device, dtype=dtype)#20, 32, 512))
# out = transformer_model(src, tgt).to(device=device, dtype=dtype) #MOVE TO CPU DEVICE????
# print(src.dtype)

class RMSLELoss(nn.Module):

    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()

    def forward(self, pred, actual):
        return self.mse(pred, actual)
        #return torch.sqrt(self.mse(torch.log(pred + 1), torch.log(actual + 1))) #requires relu after final layer to avoid negative predictions from log loss

# %%
#train the damn thing
train_losses = []
val_losses = []

num_epoch = 10#1000
min_val_loss = 1
data_folder = 'saved_models/'

learning_rate = 3.5e-5 #try smaller lr
time_shuffle = False
drop_prob = 0.1

model = MyTransformerWrapper(
    d_model=32, 
    nhead=1, 
    num_encoder_layers=6, 
    num_decoder_layers=6
).to(device)

criterion = RMSLELoss()
optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)

for epoch in range(num_epoch):
    
    model.train()
    train_loss = 0
    counter = 0
    mask = nn.Transformer.generate_square_subsequent_mask(sz=pred_length, device=device) #generate casual mask #WAIT.... DIFFERENT MASK SIZES NOT GIVING ERROR
    
    for x_batch, y_batch in train_loader: 
        x_batch = x_batch.to(device=device, dtype=dtype)
        y_batch = y_batch.to(device=device, dtype=dtype)
       
        pred = model(x_batch, y_batch, src_mask=mask, tgt_mask=mask, src_is_causal=True, tgt_is_causal=True).to(device=device)  #is the the correct place to enter the forward() parameters?
        #pred = model(x_batch, y_batch)#, src_mask=mask, tgt_mask=mask, src_is_causal=True, tgt_is_causal=True)  #is the the correct place to enter the forward() parameters?
        loss = criterion(pred, y_batch).to(device=device)
        print("loss:")
        print(loss)
        optimizer.zero_grad()
        train_loss += loss.item()
        counter += 1
        loss.backward()

        print("pred:")
        print(pred)
        print("y_batch:")
        print(y_batch)
        # Print gradients- ********************************8
        for name, param in model.named_parameters():
            if param.grad is not None:
                print(f"{name} grad mean: {param.grad.mean().item():.6f}, "
                      f"std: {param.grad.std().item():.6f}")
            else:
                print(f"{name} grad is None")

        optimizer.step()

    train_loss = train_loss/counter
    print(f'Epoch {epoch} training loss: {train_loss}')

    model.eval()
    val_loss = 0
    counter = 0
    for x_batch, y_batch in test_loader:
        x_batch = x_batch.to(device=device, dtype=dtype)
        y_batch = y_batch.to(device=device, dtype=dtype)
        with torch.no_grad():
            pred = model(x_batch, y_batch, src_mask=mask, tgt_mask=mask, src_is_causal=True, tgt_is_causal=True)
            #pred = model(x_batch, y_batch)#, src_mask=mask, tgt_mask=mask, src_is_causal=True, tgt_is_causal=True)  #is the the correct place to enter the forward() parameters?
            loss = criterion(pred,y_batch).item()
        val_loss += loss
        counter += 1
    val_loss = val_loss/counter
    print(f'Epoch {epoch} validation loss: {val_loss}')

    # for plotting train and val
    train_losses.append(train_loss)
    val_losses.append(val_loss)


    if val_loss<min_val_loss:
      print('saved...')
      torch.save(model,data_folder+'best.model')
      min_val_loss = val_loss

    scheduler.step()
# Out:
# /Users/rain/Documents/UCSD/Courses/ece176/ece176-final-project/.venv/lib/python3.13/site-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# loss:
# tensor(0.3700, device='mps:0', grad_fn=<MseLossBackward0>)
# pred:
# tensor([[[ 0.4608],
#          [ 0.8803],
#          [ 1.0983],
#          [ 0.6727],
#          [-0.2086],
#          [-0.0844]],
#
#         [[ 0.5099],
#          [ 0.7480],
#          [ 1.0290],
#          [ 0.7458],
#          [ 0.1694],
#          [ 0.0495]],
#
#         [[ 0.3885],
#          [ 0.7501],
#          [ 1.0526],
#          [ 0.8347],
#          [-0.3615],
#          [-0.1809]],
#
#         ...,
#
#         [[ 0.4154],
#          [ 0.9286],
#          [ 0.8804],
#          [ 0.5338],
#          [-0.0679],
#          [-0.0077]],
#
#         [[ 0.7333],
#          [ 0.8872],
#          [ 1.1510],
#          [ 0.7632],
#          [ 0.2059],
#          [ 0.2574]],
#
#         [[ 0.3363],
#          [ 0.7210],
#          [ 0.6976],
#          [ 0.6453],
#          [ 0.0428],
#          [ 0.0335]]], device='mps:0', grad_fn=<LinearBackward0>)
# y_batch:
# tensor([[[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         ...,
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]]], device='mps:0')
# input_projection.weight grad mean: 0.000000, std: 0.035660
# input_projection.bias grad mean: -0.000000, std: 0.112799
# transformer.encoder.layers.0.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.0.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.0.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.0.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.0.linear1.weight grad mean: 0.000000, std: 0.005137
# transformer.encoder.layers.0.linear1.bias grad mean: 0.000102, std: 0.005511
# transformer.encoder.layers.0.linear2.weight grad mean: -0.000000, std: 0.006413
# transformer.encoder.layers.0.linear2.bias grad mean: -0.000007, std: 0.048726
# transformer.encoder.layers.0.norm1.weight grad mean: -0.000195, std: 0.039550
# transformer.encoder.layers.0.norm1.bias grad mean: 0.002743, std: 0.049369
# transformer.encoder.layers.0.norm2.weight grad mean: -0.000000, std: 0.037054
# transformer.encoder.layers.0.norm2.bias grad mean: 0.000000, std: 0.048512
# transformer.encoder.layers.1.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.1.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.1.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.1.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.1.linear1.weight grad mean: -0.000000, std: 0.005043
# transformer.encoder.layers.1.linear1.bias grad mean: -0.000169, std: 0.005506
# transformer.encoder.layers.1.linear2.weight grad mean: 0.000005, std: 0.006388
# transformer.encoder.layers.1.linear2.bias grad mean: 0.000058, std: 0.048658
# transformer.encoder.layers.1.norm1.weight grad mean: -0.001610, std: 0.036738
# transformer.encoder.layers.1.norm1.bias grad mean: -0.000627, std: 0.048335
# transformer.encoder.layers.1.norm2.weight grad mean: 0.000000, std: 0.036744
# transformer.encoder.layers.1.norm2.bias grad mean: 0.000000, std: 0.048646
# transformer.encoder.layers.2.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.2.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.2.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.2.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.2.linear1.weight grad mean: -0.000000, std: 0.004840
# transformer.encoder.layers.2.linear1.bias grad mean: 0.000118, std: 0.005393
# transformer.encoder.layers.2.linear2.weight grad mean: 0.000004, std: 0.006030
# transformer.encoder.layers.2.linear2.bias grad mean: 0.000048, std: 0.046175
# transformer.encoder.layers.2.norm1.weight grad mean: 0.000780, std: 0.036961
# transformer.encoder.layers.2.norm1.bias grad mean: -0.000264, std: 0.048744
# transformer.encoder.layers.2.norm2.weight grad mean: 0.000000, std: 0.034711
# transformer.encoder.layers.2.norm2.bias grad mean: -0.000000, std: 0.046008
# transformer.encoder.layers.3.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.3.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.3.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.3.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.3.linear1.weight grad mean: -0.000000, std: 0.004527
# transformer.encoder.layers.3.linear1.bias grad mean: 0.000040, std: 0.005076
# transformer.encoder.layers.3.linear2.weight grad mean: 0.000005, std: 0.005855
# transformer.encoder.layers.3.linear2.bias grad mean: 0.000059, std: 0.045050
# transformer.encoder.layers.3.norm1.weight grad mean: 0.000253, std: 0.034721
# transformer.encoder.layers.3.norm1.bias grad mean: 0.000237, std: 0.046041
# transformer.encoder.layers.3.norm2.weight grad mean: -0.000000, std: 0.035260
# transformer.encoder.layers.3.norm2.bias grad mean: -0.000000, std: 0.046569
# transformer.encoder.layers.4.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.4.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.4.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.4.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.4.linear1.weight grad mean: 0.000000, std: 0.004586
# transformer.encoder.layers.4.linear1.bias grad mean: 0.000038, std: 0.005198
# transformer.encoder.layers.4.linear2.weight grad mean: -0.000007, std: 0.005949
# transformer.encoder.layers.4.linear2.bias grad mean: -0.000082, std: 0.045392
# transformer.encoder.layers.4.norm1.weight grad mean: -0.001587, std: 0.034849
# transformer.encoder.layers.4.norm1.bias grad mean: 0.000806, std: 0.046355
# transformer.encoder.layers.4.norm2.weight grad mean: 0.000000, std: 0.037192
# transformer.encoder.layers.4.norm2.bias grad mean: 0.000000, std: 0.047985
# transformer.encoder.layers.5.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.5.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.5.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.5.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.5.linear1.weight grad mean: -0.000000, std: 0.004394
# transformer.encoder.layers.5.linear1.bias grad mean: -0.000195, std: 0.004948
# transformer.encoder.layers.5.linear2.weight grad mean: -0.000003, std: 0.005888
# transformer.encoder.layers.5.linear2.bias grad mean: -0.000040, std: 0.046532
# transformer.encoder.layers.5.norm1.weight grad mean: 0.001295, std: 0.037521
# transformer.encoder.layers.5.norm1.bias grad mean: 0.000547, std: 0.048213
# transformer.encoder.layers.5.norm2.weight grad mean: 0.000000, std: 0.041943
# transformer.encoder.layers.5.norm2.bias grad mean: 0.000000, std: 0.048500
# transformer.encoder.norm.weight grad mean: 0.015366, std: 0.050754
# transformer.encoder.norm.bias grad mean: 0.020633, std: 0.052689
# transformer.decoder.layers.0.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.0.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.0.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.0.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.0.multihead_attn.in_proj_weight grad mean: 0.000000, std: 0.020270
# transformer.decoder.layers.0.multihead_attn.in_proj_bias grad mean: -0.001776, std: 0.024298
# transformer.decoder.layers.0.multihead_attn.out_proj.weight grad mean: -0.000909, std: 0.026916
# transformer.decoder.layers.0.multihead_attn.out_proj.bias grad mean: 0.007150, std: 0.047128
# transformer.decoder.layers.0.linear1.weight grad mean: 0.000000, std: 0.005585
# transformer.decoder.layers.0.linear1.bias grad mean: 0.000062, std: 0.005910
# transformer.decoder.layers.0.linear2.weight grad mean: -0.000003, std: 0.006763
# transformer.decoder.layers.0.linear2.bias grad mean: -0.000040, std: 0.051086
# transformer.decoder.layers.0.norm1.weight grad mean: 0.000069, std: 0.045130
# transformer.decoder.layers.0.norm1.bias grad mean: 0.000015, std: 0.048690
# transformer.decoder.layers.0.norm2.weight grad mean: -0.001100, std: 0.051798
# transformer.decoder.layers.0.norm2.bias grad mean: -0.000331, std: 0.051698
# transformer.decoder.layers.0.norm3.weight grad mean: -0.000000, std: 0.052952
# transformer.decoder.layers.0.norm3.bias grad mean: 0.000000, std: 0.051542
# transformer.decoder.layers.1.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.1.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.1.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.1.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.1.multihead_attn.in_proj_weight grad mean: -0.000000, std: 0.018780
# transformer.decoder.layers.1.multihead_attn.in_proj_bias grad mean: 0.002789, std: 0.022366
# transformer.decoder.layers.1.multihead_attn.out_proj.weight grad mean: -0.000008, std: 0.028234
# transformer.decoder.layers.1.multihead_attn.out_proj.bias grad mean: -0.003105, std: 0.043647
# transformer.decoder.layers.1.linear1.weight grad mean: 0.000000, std: 0.005868
# transformer.decoder.layers.1.linear1.bias grad mean: 0.000051, std: 0.006394
# transformer.decoder.layers.1.linear2.weight grad mean: -0.000001, std: 0.007607
# transformer.decoder.layers.1.linear2.bias grad mean: -0.000012, std: 0.054675
# transformer.decoder.layers.1.norm1.weight grad mean: -0.003092, std: 0.052643
# transformer.decoder.layers.1.norm1.bias grad mean: 0.000013, std: 0.051777
# transformer.decoder.layers.1.norm2.weight grad mean: 0.000250, std: 0.056270
# transformer.decoder.layers.1.norm2.bias grad mean: -0.001729, std: 0.057504
# transformer.decoder.layers.1.norm3.weight grad mean: -0.000000, std: 0.050812
# transformer.decoder.layers.1.norm3.bias grad mean: -0.000000, std: 0.054704
# transformer.decoder.layers.2.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.2.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.2.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.2.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.2.multihead_attn.in_proj_weight grad mean: 0.000000, std: 0.022293
# transformer.decoder.layers.2.multihead_attn.in_proj_bias grad mean: 0.001034, std: 0.026247
# transformer.decoder.layers.2.multihead_attn.out_proj.weight grad mean: 0.000840, std: 0.027534
# transformer.decoder.layers.2.multihead_attn.out_proj.bias grad mean: -0.008270, std: 0.041116
# transformer.decoder.layers.2.linear1.weight grad mean: 0.000000, std: 0.007716
# transformer.decoder.layers.2.linear1.bias grad mean: 0.000016, std: 0.008256
# transformer.decoder.layers.2.linear2.weight grad mean: -0.000009, std: 0.009557
# transformer.decoder.layers.2.linear2.bias grad mean: -0.000106, std: 0.071396
# transformer.decoder.layers.2.norm1.weight grad mean: -0.006367, std: 0.051361
# transformer.decoder.layers.2.norm1.bias grad mean: 0.000745, std: 0.055317
# transformer.decoder.layers.2.norm2.weight grad mean: 0.000165, std: 0.074264
# transformer.decoder.layers.2.norm2.bias grad mean: -0.002084, std: 0.071871
# transformer.decoder.layers.2.norm3.weight grad mean: -0.000000, std: 0.069681
# transformer.decoder.layers.2.norm3.bias grad mean: 0.000000, std: 0.070681
# transformer.decoder.layers.3.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.3.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.3.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.3.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.3.multihead_attn.in_proj_weight grad mean: 0.000000, std: 0.027640
# transformer.decoder.layers.3.multihead_attn.in_proj_bias grad mean: -0.001180, std: 0.032906
# transformer.decoder.layers.3.multihead_attn.out_proj.weight grad mean: 0.000742, std: 0.030643
# transformer.decoder.layers.3.multihead_attn.out_proj.bias grad mean: -0.008380, std: 0.058759
# transformer.decoder.layers.3.linear1.weight grad mean: 0.000000, std: 0.007220
# transformer.decoder.layers.3.linear1.bias grad mean: 0.000148, std: 0.007898
# transformer.decoder.layers.3.linear2.weight grad mean: 0.000004, std: 0.009230
# transformer.decoder.layers.3.linear2.bias grad mean: 0.000042, std: 0.068412
# transformer.decoder.layers.3.norm1.weight grad mean: -0.002152, std: 0.066852
# transformer.decoder.layers.3.norm1.bias grad mean: -0.000006, std: 0.070678
# transformer.decoder.layers.3.norm2.weight grad mean: 0.000855, std: 0.067365
# transformer.decoder.layers.3.norm2.bias grad mean: -0.000286, std: 0.071534
# transformer.decoder.layers.3.norm3.weight grad mean: -0.000000, std: 0.065152
# transformer.decoder.layers.3.norm3.bias grad mean: -0.000000, std: 0.071742
# transformer.decoder.layers.4.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.4.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.4.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.4.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.4.multihead_attn.in_proj_weight grad mean: -0.000000, std: 0.024035
# transformer.decoder.layers.4.multihead_attn.in_proj_bias grad mean: -0.000452, std: 0.027460
# transformer.decoder.layers.4.multihead_attn.out_proj.weight grad mean: -0.000363, std: 0.033025
# transformer.decoder.layers.4.multihead_attn.out_proj.bias grad mean: -0.005067, std: 0.051353
# transformer.decoder.layers.4.linear1.weight grad mean: 0.000000, std: 0.008103
# transformer.decoder.layers.4.linear1.bias grad mean: 0.000287, std: 0.008915
# transformer.decoder.layers.4.linear2.weight grad mean: -0.000005, std: 0.010505
# transformer.decoder.layers.4.linear2.bias grad mean: -0.000054, std: 0.078988
# transformer.decoder.layers.4.norm1.weight grad mean: -0.000028, std: 0.064949
# transformer.decoder.layers.4.norm1.bias grad mean: -0.000032, std: 0.071736
# transformer.decoder.layers.4.norm2.weight grad mean: 0.000173, std: 0.069385
# transformer.decoder.layers.4.norm2.bias grad mean: 0.002059, std: 0.079515
# transformer.decoder.layers.4.norm3.weight grad mean: -0.000000, std: 0.060533
# transformer.decoder.layers.4.norm3.bias grad mean: 0.000000, std: 0.081669
# transformer.decoder.layers.5.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.5.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.5.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.5.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.5.multihead_attn.in_proj_weight grad mean: 0.000000, std: 0.025911
# transformer.decoder.layers.5.multihead_attn.in_proj_bias grad mean: 0.001068, std: 0.031247
# transformer.decoder.layers.5.multihead_attn.out_proj.weight grad mean: -0.001106, std: 0.036172
# transformer.decoder.layers.5.multihead_attn.out_proj.bias grad mean: -0.008574, std: 0.058768
# transformer.decoder.layers.5.linear1.weight grad mean: -0.000000, std: 0.008735
# transformer.decoder.layers.5.linear1.bias grad mean: 0.000108, std: 0.009599
# transformer.decoder.layers.5.linear2.weight grad mean: 0.000004, std: 0.011861
# transformer.decoder.layers.5.linear2.bias grad mean: 0.000056, std: 0.090273
# transformer.decoder.layers.5.norm1.weight grad mean: -0.006667, std: 0.059844
# transformer.decoder.layers.5.norm1.bias grad mean: 0.000369, std: 0.081958
# transformer.decoder.layers.5.norm2.weight grad mean: -0.001361, std: 0.062672
# transformer.decoder.layers.5.norm2.bias grad mean: -0.002321, std: 0.093075
# transformer.decoder.layers.5.norm3.weight grad mean: 0.000000, std: 0.066034
# transformer.decoder.layers.5.norm3.bias grad mean: 0.000000, std: 0.092692
# transformer.decoder.norm.weight grad mean: 0.011325, std: 0.078966
# transformer.decoder.norm.bias grad mean: 0.019401, std: 0.094692
# output_projection.weight grad mean: 0.000000, std: 0.838674
# output_projection.bias grad mean: 0.922467, std: nan
# loss:
# tensor(0.1813, device='mps:0', grad_fn=<MseLossBackward0>)
# pred:
# tensor([[[ 0.3215],
#          [ 0.6793],
#          [ 0.7595],
#          [ 0.4410],
#          [-0.3261],
#          [-0.3696]],
#
#         [[ 0.2165],
#          [ 0.8490],
#          [ 0.8260],
#          [ 0.3633],
#          [-0.1075],
#          [-0.3121]],
#
#         [[ 0.2872],
#          [ 0.6202],
#          [ 0.7859],
#          [ 0.2309],
#          [-0.4936],
#          [-0.0152]],
#
#         ...,
#
#         [[ 0.3514],
#          [ 0.6957],
#          [ 0.7454],
#          [-0.0436],
#          [-0.2925],
#          [-0.2234]],
#
#         [[ 0.3305],
#          [ 0.1499],
#          [ 0.6268],
#          [ 0.7069],
#          [-0.1466],
#          [-0.1727]],
#
#         [[ 0.2806],
#          [ 0.8524],
#          [ 0.6440],
#          [ 0.3962],
#          [-0.0936],
#          [-0.3856]]], device='mps:0', grad_fn=<LinearBackward0>)
# y_batch:
# tensor([[[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         ...,
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]]], device='mps:0')
# input_projection.weight grad mean: -0.000000, std: 0.032097
# input_projection.bias grad mean: -0.000000, std: 0.059640
# transformer.encoder.layers.0.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.0.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.0.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.0.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.0.linear1.weight grad mean: -0.000000, std: 0.002929
# transformer.encoder.layers.0.linear1.bias grad mean: 0.000031, std: 0.003115
# transformer.encoder.layers.0.linear2.weight grad mean: -0.000002, std: 0.003656
# transformer.encoder.layers.0.linear2.bias grad mean: -0.000024, std: 0.027658
# transformer.encoder.layers.0.norm1.weight grad mean: 0.000013, std: 0.024564
# transformer.encoder.layers.0.norm1.bias grad mean: 0.001424, std: 0.028174
# transformer.encoder.layers.0.norm2.weight grad mean: 0.000001, std: 0.023356
# transformer.encoder.layers.0.norm2.bias grad mean: 0.000000, std: 0.027601
# transformer.encoder.layers.1.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.1.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.1.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.1.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.1.linear1.weight grad mean: 0.000000, std: 0.002941
# transformer.encoder.layers.1.linear1.bias grad mean: -0.000084, std: 0.003174
# transformer.encoder.layers.1.linear2.weight grad mean: 0.000005, std: 0.003680
# transformer.encoder.layers.1.linear2.bias grad mean: 0.000061, std: 0.027776
# transformer.encoder.layers.1.norm1.weight grad mean: -0.000999, std: 0.023126
# transformer.encoder.layers.1.norm1.bias grad mean: -0.000844, std: 0.027530
# transformer.encoder.layers.1.norm2.weight grad mean: 0.000001, std: 0.023615
# transformer.encoder.layers.1.norm2.bias grad mean: -0.000000, std: 0.027808
# transformer.encoder.layers.2.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.2.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.2.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.2.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.2.linear1.weight grad mean: -0.000000, std: 0.002884
# transformer.encoder.layers.2.linear1.bias grad mean: 0.000033, std: 0.003185
# transformer.encoder.layers.2.linear2.weight grad mean: -0.000003, std: 0.003551
# transformer.encoder.layers.2.linear2.bias grad mean: -0.000036, std: 0.026987
# transformer.encoder.layers.2.norm1.weight grad mean: 0.000451, std: 0.023762
# transformer.encoder.layers.2.norm1.bias grad mean: -0.000050, std: 0.027855
# transformer.encoder.layers.2.norm2.weight grad mean: 0.000001, std: 0.022077
# transformer.encoder.layers.2.norm2.bias grad mean: -0.000000, std: 0.026837
# transformer.encoder.layers.3.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.3.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.3.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.3.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.3.linear1.weight grad mean: -0.000000, std: 0.002617
# transformer.encoder.layers.3.linear1.bias grad mean: 0.000017, std: 0.002907
# transformer.encoder.layers.3.linear2.weight grad mean: 0.000001, std: 0.003447
# transformer.encoder.layers.3.linear2.bias grad mean: 0.000012, std: 0.026363
# transformer.encoder.layers.3.norm1.weight grad mean: 0.000052, std: 0.022064
# transformer.encoder.layers.3.norm1.bias grad mean: -0.000145, std: 0.026843
# transformer.encoder.layers.3.norm2.weight grad mean: 0.000001, std: 0.023251
# transformer.encoder.layers.3.norm2.bias grad mean: -0.000000, std: 0.027281
# transformer.encoder.layers.4.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.4.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.4.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.4.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.4.linear1.weight grad mean: -0.000000, std: 0.002775
# transformer.encoder.layers.4.linear1.bias grad mean: 0.000040, std: 0.003119
# transformer.encoder.layers.4.linear2.weight grad mean: -0.000001, std: 0.003514
# transformer.encoder.layers.4.linear2.bias grad mean: -0.000011, std: 0.026669
# transformer.encoder.layers.4.norm1.weight grad mean: -0.000994, std: 0.022939
# transformer.encoder.layers.4.norm1.bias grad mean: 0.000303, std: 0.027159
# transformer.encoder.layers.4.norm2.weight grad mean: 0.000001, std: 0.023484
# transformer.encoder.layers.4.norm2.bias grad mean: 0.000000, std: 0.028037
# transformer.encoder.layers.5.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.5.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.5.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.5.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.encoder.layers.5.linear1.weight grad mean: 0.000000, std: 0.002575
# transformer.encoder.layers.5.linear1.bias grad mean: -0.000113, std: 0.002869
# transformer.encoder.layers.5.linear2.weight grad mean: 0.000000, std: 0.003414
# transformer.encoder.layers.5.linear2.bias grad mean: 0.000002, std: 0.026807
# transformer.encoder.layers.5.norm1.weight grad mean: 0.000527, std: 0.023620
# transformer.encoder.layers.5.norm1.bias grad mean: 0.000297, std: 0.028093
# transformer.encoder.layers.5.norm2.weight grad mean: 0.000001, std: 0.026874
# transformer.encoder.layers.5.norm2.bias grad mean: -0.000000, std: 0.027998
# transformer.encoder.norm.weight grad mean: 0.006042, std: 0.031680
# transformer.encoder.norm.bias grad mean: 0.012022, std: 0.029502
# transformer.decoder.layers.0.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.0.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.0.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.0.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.0.multihead_attn.in_proj_weight grad mean: 0.000000, std: 0.012526
# transformer.decoder.layers.0.multihead_attn.in_proj_bias grad mean: -0.001211, std: 0.015028
# transformer.decoder.layers.0.multihead_attn.out_proj.weight grad mean: -0.000444, std: 0.016026
# transformer.decoder.layers.0.multihead_attn.out_proj.bias grad mean: 0.002832, std: 0.027472
# transformer.decoder.layers.0.linear1.weight grad mean: -0.000000, std: 0.003418
# transformer.decoder.layers.0.linear1.bias grad mean: -0.000000, std: 0.003264
# transformer.decoder.layers.0.linear2.weight grad mean: 0.000001, std: 0.003821
# transformer.decoder.layers.0.linear2.bias grad mean: 0.000012, std: 0.026409
# transformer.decoder.layers.0.norm1.weight grad mean: 0.000485, std: 0.026314
# transformer.decoder.layers.0.norm1.bias grad mean: 0.000040, std: 0.025964
# transformer.decoder.layers.0.norm2.weight grad mean: -0.000539, std: 0.030129
# transformer.decoder.layers.0.norm2.bias grad mean: 0.000128, std: 0.026948
# transformer.decoder.layers.0.norm3.weight grad mean: 0.000002, std: 0.030866
# transformer.decoder.layers.0.norm3.bias grad mean: 0.000000, std: 0.027046
# transformer.decoder.layers.1.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.1.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.1.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.1.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.1.multihead_attn.in_proj_weight grad mean: -0.000000, std: 0.010603
# transformer.decoder.layers.1.multihead_attn.in_proj_bias grad mean: 0.001513, std: 0.012709
# transformer.decoder.layers.1.multihead_attn.out_proj.weight grad mean: 0.000001, std: 0.016907
# transformer.decoder.layers.1.multihead_attn.out_proj.bias grad mean: -0.000263, std: 0.025991
# transformer.decoder.layers.1.linear1.weight grad mean: -0.000000, std: 0.003700
# transformer.decoder.layers.1.linear1.bias grad mean: 0.000032, std: 0.003510
# transformer.decoder.layers.1.linear2.weight grad mean: -0.000000, std: 0.004340
# transformer.decoder.layers.1.linear2.bias grad mean: -0.000001, std: 0.027591
# transformer.decoder.layers.1.norm1.weight grad mean: -0.001138, std: 0.030507
# transformer.decoder.layers.1.norm1.bias grad mean: 0.000006, std: 0.027059
# transformer.decoder.layers.1.norm2.weight grad mean: -0.000091, std: 0.034541
# transformer.decoder.layers.1.norm2.bias grad mean: -0.000805, std: 0.029396
# transformer.decoder.layers.1.norm3.weight grad mean: 0.000002, std: 0.031915
# transformer.decoder.layers.1.norm3.bias grad mean: -0.000000, std: 0.027694
# transformer.decoder.layers.2.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.2.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.2.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.2.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.2.multihead_attn.in_proj_weight grad mean: -0.000000, std: 0.012720
# transformer.decoder.layers.2.multihead_attn.in_proj_bias grad mean: 0.001141, std: 0.014777
# transformer.decoder.layers.2.multihead_attn.out_proj.weight grad mean: 0.000445, std: 0.015751
# transformer.decoder.layers.2.multihead_attn.out_proj.bias grad mean: -0.004847, std: 0.023319
# transformer.decoder.layers.2.linear1.weight grad mean: 0.000000, std: 0.004473
# transformer.decoder.layers.2.linear1.bias grad mean: -0.000012, std: 0.004340
# transformer.decoder.layers.2.linear2.weight grad mean: -0.000016, std: 0.005144
# transformer.decoder.layers.2.linear2.bias grad mean: -0.000198, std: 0.035121
# transformer.decoder.layers.2.norm1.weight grad mean: -0.003235, std: 0.031772
# transformer.decoder.layers.2.norm1.bias grad mean: 0.000565, std: 0.027902
# transformer.decoder.layers.2.norm2.weight grad mean: -0.000029, std: 0.043985
# transformer.decoder.layers.2.norm2.bias grad mean: -0.000985, std: 0.035453
# transformer.decoder.layers.2.norm3.weight grad mean: 0.000002, std: 0.041883
# transformer.decoder.layers.2.norm3.bias grad mean: -0.000000, std: 0.034619
# transformer.decoder.layers.3.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.3.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.3.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.3.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.3.multihead_attn.in_proj_weight grad mean: 0.000000, std: 0.015680
# transformer.decoder.layers.3.multihead_attn.in_proj_bias grad mean: -0.000358, std: 0.018738
# transformer.decoder.layers.3.multihead_attn.out_proj.weight grad mean: 0.000366, std: 0.017631
# transformer.decoder.layers.3.multihead_attn.out_proj.bias grad mean: -0.004339, std: 0.033016
# transformer.decoder.layers.3.linear1.weight grad mean: -0.000000, std: 0.004323
# transformer.decoder.layers.3.linear1.bias grad mean: 0.000063, std: 0.004206
# transformer.decoder.layers.3.linear2.weight grad mean: 0.000012, std: 0.005107
# transformer.decoder.layers.3.linear2.bias grad mean: 0.000138, std: 0.034345
# transformer.decoder.layers.3.norm1.weight grad mean: -0.000775, std: 0.040994
# transformer.decoder.layers.3.norm1.bias grad mean: -0.000003, std: 0.034635
# transformer.decoder.layers.3.norm2.weight grad mean: 0.000350, std: 0.042285
# transformer.decoder.layers.3.norm2.bias grad mean: -0.000538, std: 0.035555
# transformer.decoder.layers.3.norm3.weight grad mean: 0.000002, std: 0.042863
# transformer.decoder.layers.3.norm3.bias grad mean: 0.000000, std: 0.035680
# transformer.decoder.layers.4.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.4.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.4.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.4.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.4.multihead_attn.in_proj_weight grad mean: -0.000000, std: 0.014137
# transformer.decoder.layers.4.multihead_attn.in_proj_bias grad mean: 0.000256, std: 0.016061
# transformer.decoder.layers.4.multihead_attn.out_proj.weight grad mean: -0.000135, std: 0.017919
# transformer.decoder.layers.4.multihead_attn.out_proj.bias grad mean: -0.002215, std: 0.028118
# transformer.decoder.layers.4.linear1.weight grad mean: 0.000000, std: 0.004729
# transformer.decoder.layers.4.linear1.bias grad mean: 0.000163, std: 0.004629
# transformer.decoder.layers.4.linear2.weight grad mean: -0.000011, std: 0.005587
# transformer.decoder.layers.4.linear2.bias grad mean: -0.000131, std: 0.037962
# transformer.decoder.layers.4.norm1.weight grad mean: 0.000355, std: 0.042870
# transformer.decoder.layers.4.norm1.bias grad mean: -0.000031, std: 0.035672
# transformer.decoder.layers.4.norm2.weight grad mean: -0.000224, std: 0.041293
# transformer.decoder.layers.4.norm2.bias grad mean: 0.001256, std: 0.038718
# transformer.decoder.layers.4.norm3.weight grad mean: 0.000002, std: 0.036308
# transformer.decoder.layers.4.norm3.bias grad mean: -0.000000, std: 0.038820
# transformer.decoder.layers.5.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.5.self_attn.in_proj_bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.5.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.5.self_attn.out_proj.bias grad mean: 0.000000, std: 0.000000
# transformer.decoder.layers.5.multihead_attn.in_proj_weight grad mean: -0.000000, std: 0.014926
# transformer.decoder.layers.5.multihead_attn.in_proj_bias grad mean: 0.000486, std: 0.018131
# transformer.decoder.layers.5.multihead_attn.out_proj.weight grad mean: -0.000333, std: 0.020291
# transformer.decoder.layers.5.multihead_attn.out_proj.bias grad mean: -0.002500, std: 0.034258
# transformer.decoder.layers.5.linear1.weight grad mean: -0.000000, std: 0.004971
# transformer.decoder.layers.5.linear1.bias grad mean: 0.000002, std: 0.004874
# transformer.decoder.layers.5.linear2.weight grad mean: 0.000005, std: 0.006245
# transformer.decoder.layers.5.linear2.bias grad mean: 0.000064, std: 0.043366
# transformer.decoder.layers.5.norm1.weight grad mean: -0.003790, std: 0.035868
# transformer.decoder.layers.5.norm1.bias grad mean: 0.000047, std: 0.039011
# transformer.decoder.layers.5.norm2.weight grad mean: -0.000718, std: 0.037697
# transformer.decoder.layers.5.norm2.bias grad mean: -0.001044, std: 0.044956
# transformer.decoder.layers.5.norm3.weight grad mean: 0.000002, std: 0.038207
# transformer.decoder.layers.5.norm3.bias grad mean: 0.000000, std: 0.044550
# transformer.decoder.norm.weight grad mean: -0.000938, std: 0.040915
# transformer.decoder.norm.bias grad mean: 0.009151, std: 0.044650
# output_projection.weight grad mean: -0.000003, std: 0.465723
# output_projection.bias grad mean: 0.434960, std: nan
# loss:
# tensor(0.5267, device='mps:0', grad_fn=<MseLossBackward0>)
# pred:
# tensor([[[ 0.1282],
#          [ 0.5015],
#          [ 0.4154],
#          [ 0.3530],
#          [-0.2366],
#          [-0.1057]],
#
#         [[ 0.5861],
#          [ 0.0973],
#          [ 0.3862],
#          [ 0.4967],
#          [ 0.2938],
#          [ 0.2109]],
#
#         [[-0.4427],
#          [ 0.2571],
#          [ 0.2775],
#          [ 0.4617],
#          [-0.4709],
#          [ 0.4910]],
#
#         ...,
#
#         [[ 0.3129],
#          [ 0.2213],
#          [ 0.7702],
#          [ 0.7320],
#          [ 0.9432],
#          [ 0.0189]],
#
#         [[ 0.2415],
#          [ 0.2682],
#          [ 0.7608],
#          [ 0.0810],
#          [-0.4991],
#          [-0.0414]],
#
#         [[-0.0165],
#          [ 0.5927],
#          [ 0.4628],
#          [ 0.2775],
#          [-0.2923],
#          [ 0.1732]]], device='mps:0', grad_fn=<LinearBackward0>)
# y_batch:
# tensor([[[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         ...,
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]]], device='mps:0')
# input_projection.weight grad mean: 0.001262, std: 0.044033
# input_projection.bias grad mean: -0.000202, std: 0.050539
# transformer.encoder.layers.0.self_attn.in_proj_weight grad mean: 0.000134, std: 0.008314
# transformer.encoder.layers.0.self_attn.in_proj_bias grad mean: -0.002111, std: 0.013747
# transformer.encoder.layers.0.self_attn.out_proj.weight grad mean: 0.000008, std: 0.010488
# transformer.encoder.layers.0.self_attn.out_proj.bias grad mean: -0.001066, std: 0.023066
# transformer.encoder.layers.0.linear1.weight grad mean: -0.000000, std: 0.002773
# transformer.encoder.layers.0.linear1.bias grad mean: 0.000122, std: 0.003161
# transformer.encoder.layers.0.linear2.weight grad mean: 0.000007, std: 0.003736
# transformer.encoder.layers.0.linear2.bias grad mean: 0.000085, std: 0.029270
# transformer.encoder.layers.0.norm1.weight grad mean: -0.000150, std: 0.018933
# transformer.encoder.layers.0.norm1.bias grad mean: 0.002321, std: 0.028410
# transformer.encoder.layers.0.norm2.weight grad mean: 0.000132, std: 0.019218
# transformer.encoder.layers.0.norm2.bias grad mean: -0.001674, std: 0.029626
# transformer.encoder.layers.1.self_attn.in_proj_weight grad mean: -0.000000, std: 0.005780
# transformer.encoder.layers.1.self_attn.in_proj_bias grad mean: 0.000303, std: 0.006460
# transformer.encoder.layers.1.self_attn.out_proj.weight grad mean: -0.000128, std: 0.005802
# transformer.encoder.layers.1.self_attn.out_proj.bias grad mean: -0.001270, std: 0.011579
# transformer.encoder.layers.1.linear1.weight grad mean: 0.000000, std: 0.002490
# transformer.encoder.layers.1.linear1.bias grad mean: -0.000024, std: 0.003031
# transformer.encoder.layers.1.linear2.weight grad mean: -0.000008, std: 0.003511
# transformer.encoder.layers.1.linear2.bias grad mean: -0.000093, std: 0.027403
# transformer.encoder.layers.1.norm1.weight grad mean: -0.000809, std: 0.018562
# transformer.encoder.layers.1.norm1.bias grad mean: 0.000332, std: 0.028667
# transformer.encoder.layers.1.norm2.weight grad mean: -0.000032, std: 0.019505
# transformer.encoder.layers.1.norm2.bias grad mean: -0.000207, std: 0.027540
# transformer.encoder.layers.2.self_attn.in_proj_weight grad mean: -0.000000, std: 0.005063
# transformer.encoder.layers.2.self_attn.in_proj_bias grad mean: -0.000005, std: 0.006388
# transformer.encoder.layers.2.self_attn.out_proj.weight grad mean: 0.000064, std: 0.005280
# transformer.encoder.layers.2.self_attn.out_proj.bias grad mean: 0.000880, std: 0.011251
# transformer.encoder.layers.2.linear1.weight grad mean: -0.000000, std: 0.002293
# transformer.encoder.layers.2.linear1.bias grad mean: 0.000039, std: 0.002860
# transformer.encoder.layers.2.linear2.weight grad mean: 0.000007, std: 0.003230
# transformer.encoder.layers.2.linear2.bias grad mean: 0.000088, std: 0.026457
# transformer.encoder.layers.2.norm1.weight grad mean: 0.000426, std: 0.017694
# transformer.encoder.layers.2.norm1.bias grad mean: 0.000123, std: 0.026599
# transformer.encoder.layers.2.norm2.weight grad mean: -0.000086, std: 0.015690
# transformer.encoder.layers.2.norm2.bias grad mean: 0.000838, std: 0.026088
# transformer.encoder.layers.3.self_attn.in_proj_weight grad mean: 0.000000, std: 0.006314
# transformer.encoder.layers.3.self_attn.in_proj_bias grad mean: -0.000612, std: 0.008314
# transformer.encoder.layers.3.self_attn.out_proj.weight grad mean: -0.000109, std: 0.008730
# transformer.encoder.layers.3.self_attn.out_proj.bias grad mean: -0.001078, std: 0.016193
# transformer.encoder.layers.3.linear1.weight grad mean: 0.000000, std: 0.002238
# transformer.encoder.layers.3.linear1.bias grad mean: -0.000082, std: 0.002928
# transformer.encoder.layers.3.linear2.weight grad mean: 0.000003, std: 0.003545
# transformer.encoder.layers.3.linear2.bias grad mean: 0.000034, std: 0.028910
# transformer.encoder.layers.3.norm1.weight grad mean: 0.000362, std: 0.021558
# transformer.encoder.layers.3.norm1.bias grad mean: -0.000986, std: 0.029124
# transformer.encoder.layers.3.norm2.weight grad mean: 0.000075, std: 0.022828
# transformer.encoder.layers.3.norm2.bias grad mean: 0.001988, std: 0.030292
# transformer.encoder.layers.4.self_attn.in_proj_weight grad mean: 0.000000, std: 0.005648
# transformer.encoder.layers.4.self_attn.in_proj_bias grad mean: -0.000105, std: 0.007379
# transformer.encoder.layers.4.self_attn.out_proj.weight grad mean: -0.000026, std: 0.006573
# transformer.encoder.layers.4.self_attn.out_proj.bias grad mean: -0.003786, std: 0.014480
# transformer.encoder.layers.4.linear1.weight grad mean: -0.000000, std: 0.002612
# transformer.encoder.layers.4.linear1.bias grad mean: 0.000093, std: 0.003432
# transformer.encoder.layers.4.linear2.weight grad mean: -0.000011, std: 0.003977
# transformer.encoder.layers.4.linear2.bias grad mean: -0.000135, std: 0.032966
# transformer.encoder.layers.4.norm1.weight grad mean: -0.000986, std: 0.020875
# transformer.encoder.layers.4.norm1.bias grad mean: -0.000186, std: 0.033465
# transformer.encoder.layers.4.norm2.weight grad mean: 0.000004, std: 0.023746
# transformer.encoder.layers.4.norm2.bias grad mean: 0.003653, std: 0.034406
# transformer.encoder.layers.5.self_attn.in_proj_weight grad mean: -0.000000, std: 0.008623
# transformer.encoder.layers.5.self_attn.in_proj_bias grad mean: 0.000700, std: 0.011236
# transformer.encoder.layers.5.self_attn.out_proj.weight grad mean: -0.000156, std: 0.009985
# transformer.encoder.layers.5.self_attn.out_proj.bias grad mean: -0.001803, std: 0.018734
# transformer.encoder.layers.5.linear1.weight grad mean: -0.000000, std: 0.002658
# transformer.encoder.layers.5.linear1.bias grad mean: 0.000041, std: 0.003607
# transformer.encoder.layers.5.linear2.weight grad mean: 0.000003, std: 0.004062
# transformer.encoder.layers.5.linear2.bias grad mean: 0.000039, std: 0.034643
# transformer.encoder.layers.5.norm1.weight grad mean: 0.000127, std: 0.022429
# transformer.encoder.layers.5.norm1.bias grad mean: 0.000639, std: 0.036594
# transformer.encoder.layers.5.norm2.weight grad mean: 0.000000, std: 0.023651
# transformer.encoder.layers.5.norm2.bias grad mean: 0.000000, std: 0.036150
# transformer.encoder.norm.weight grad mean: 0.001380, std: 0.026188
# transformer.encoder.norm.bias grad mean: 0.014091, std: 0.037005
# transformer.decoder.layers.0.self_attn.in_proj_weight grad mean: 0.000135, std: 0.007093
# transformer.decoder.layers.0.self_attn.in_proj_bias grad mean: -0.001590, std: 0.011335
# transformer.decoder.layers.0.self_attn.out_proj.weight grad mean: -0.000087, std: 0.008926
# transformer.decoder.layers.0.self_attn.out_proj.bias grad mean: -0.002866, std: 0.018136
# transformer.decoder.layers.0.multihead_attn.in_proj_weight grad mean: 0.000000, std: 0.011115
# transformer.decoder.layers.0.multihead_attn.in_proj_bias grad mean: -0.000409, std: 0.014592
# transformer.decoder.layers.0.multihead_attn.out_proj.weight grad mean: -0.000238, std: 0.014044
# transformer.decoder.layers.0.multihead_attn.out_proj.bias grad mean: 0.000869, std: 0.024685
# transformer.decoder.layers.0.linear1.weight grad mean: 0.000000, std: 0.003533
# transformer.decoder.layers.0.linear1.bias grad mean: -0.000051, std: 0.002866
# transformer.decoder.layers.0.linear2.weight grad mean: 0.000007, std: 0.003566
# transformer.decoder.layers.0.linear2.bias grad mean: 0.000094, std: 0.019903
# transformer.decoder.layers.0.norm1.weight grad mean: -0.000288, std: 0.026210
# transformer.decoder.layers.0.norm1.bias grad mean: 0.000005, std: 0.018947
# transformer.decoder.layers.0.norm2.weight grad mean: 0.000120, std: 0.031985
# transformer.decoder.layers.0.norm2.bias grad mean: 0.001719, std: 0.020952
# transformer.decoder.layers.0.norm3.weight grad mean: -0.000334, std: 0.030909
# transformer.decoder.layers.0.norm3.bias grad mean: -0.000213, std: 0.020454
# transformer.decoder.layers.1.self_attn.in_proj_weight grad mean: -0.000000, std: 0.007341
# transformer.decoder.layers.1.self_attn.in_proj_bias grad mean: 0.000616, std: 0.008166
# transformer.decoder.layers.1.self_attn.out_proj.weight grad mean: -0.000010, std: 0.011263
# transformer.decoder.layers.1.self_attn.out_proj.bias grad mean: 0.005229, std: 0.015156
# transformer.decoder.layers.1.multihead_attn.in_proj_weight grad mean: -0.000000, std: 0.008513
# transformer.decoder.layers.1.multihead_attn.in_proj_bias grad mean: 0.000253, std: 0.011334
# transformer.decoder.layers.1.multihead_attn.out_proj.weight grad mean: 0.000008, std: 0.011840
# transformer.decoder.layers.1.multihead_attn.out_proj.bias grad mean: -0.002293, std: 0.022126
# transformer.decoder.layers.1.linear1.weight grad mean: 0.000000, std: 0.003616
# transformer.decoder.layers.1.linear1.bias grad mean: 0.000025, std: 0.002756
# transformer.decoder.layers.1.linear2.weight grad mean: 0.000008, std: 0.003774
# transformer.decoder.layers.1.linear2.bias grad mean: 0.000104, std: 0.017219
# transformer.decoder.layers.1.norm1.weight grad mean: -0.000568, std: 0.028153
# transformer.decoder.layers.1.norm1.bias grad mean: -0.000096, std: 0.016634
# transformer.decoder.layers.1.norm2.weight grad mean: -0.000202, std: 0.033296
# transformer.decoder.layers.1.norm2.bias grad mean: -0.000264, std: 0.017650
# transformer.decoder.layers.1.norm3.weight grad mean: 0.000152, std: 0.032506
# transformer.decoder.layers.1.norm3.bias grad mean: 0.000028, std: 0.017560
# transformer.decoder.layers.2.self_attn.in_proj_weight grad mean: -0.000000, std: 0.004370
# transformer.decoder.layers.2.self_attn.in_proj_bias grad mean: 0.001114, std: 0.004800
# transformer.decoder.layers.2.self_attn.out_proj.weight grad mean: 0.000010, std: 0.004365
# transformer.decoder.layers.2.self_attn.out_proj.bias grad mean: -0.000685, std: 0.008415
# transformer.decoder.layers.2.multihead_attn.in_proj_weight grad mean: -0.000000, std: 0.009686
# transformer.decoder.layers.2.multihead_attn.in_proj_bias grad mean: 0.000472, std: 0.013119
# transformer.decoder.layers.2.multihead_attn.out_proj.weight grad mean: 0.000325, std: 0.014340
# transformer.decoder.layers.2.multihead_attn.out_proj.bias grad mean: -0.004330, std: 0.027072
# transformer.decoder.layers.2.linear1.weight grad mean: 0.000000, std: 0.004122
# transformer.decoder.layers.2.linear1.bias grad mean: -0.000050, std: 0.003094
# transformer.decoder.layers.2.linear2.weight grad mean: -0.000011, std: 0.004178
# transformer.decoder.layers.2.linear2.bias grad mean: -0.000133, std: 0.019289
# transformer.decoder.layers.2.norm1.weight grad mean: -0.001193, std: 0.032364
# transformer.decoder.layers.2.norm1.bias grad mean: 0.000153, std: 0.017962
# transformer.decoder.layers.2.norm2.weight grad mean: -0.000044, std: 0.034659
# transformer.decoder.layers.2.norm2.bias grad mean: 0.000483, std: 0.018152
# transformer.decoder.layers.2.norm3.weight grad mean: -0.000136, std: 0.035483
# transformer.decoder.layers.2.norm3.bias grad mean: -0.000548, std: 0.019703
# transformer.decoder.layers.3.self_attn.in_proj_weight grad mean: 0.000000, std: 0.006115
# transformer.decoder.layers.3.self_attn.in_proj_bias grad mean: -0.000340, std: 0.006593
# transformer.decoder.layers.3.self_attn.out_proj.weight grad mean: -0.000007, std: 0.008415
# transformer.decoder.layers.3.self_attn.out_proj.bias grad mean: 0.000206, std: 0.012265
# transformer.decoder.layers.3.multihead_attn.in_proj_weight grad mean: 0.000000, std: 0.008634
# transformer.decoder.layers.3.multihead_attn.in_proj_bias grad mean: -0.001078, std: 0.011553
# transformer.decoder.layers.3.multihead_attn.out_proj.weight grad mean: -0.000031, std: 0.013734
# transformer.decoder.layers.3.multihead_attn.out_proj.bias grad mean: -0.001608, std: 0.027513
# transformer.decoder.layers.3.linear1.weight grad mean: -0.000000, std: 0.004440
# transformer.decoder.layers.3.linear1.bias grad mean: 0.000071, std: 0.003433
# transformer.decoder.layers.3.linear2.weight grad mean: 0.000007, std: 0.004650
# transformer.decoder.layers.3.linear2.bias grad mean: 0.000084, std: 0.022517
# transformer.decoder.layers.3.norm1.weight grad mean: 0.000186, std: 0.034205
# transformer.decoder.layers.3.norm1.bias grad mean: 0.000021, std: 0.021664
# transformer.decoder.layers.3.norm2.weight grad mean: 0.000594, std: 0.039829
# transformer.decoder.layers.3.norm2.bias grad mean: 0.000391, std: 0.022675
# transformer.decoder.layers.3.norm3.weight grad mean: -0.000020, std: 0.043803
# ...
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         ...,
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]],
#
#         [[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589]]], device='mps:0')
# input_projection.weight grad mean: 0.000187, std: 0.004153
# input_projection.bias grad mean: 0.000504, std: 0.006420
# transformer.encoder.layers.0.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000511
# transformer.encoder.layers.0.self_attn.in_proj_bias grad mean: -0.000028, std: 0.000852
# transformer.encoder.layers.0.self_attn.out_proj.weight grad mean: 0.000006, std: 0.000770
# transformer.encoder.layers.0.self_attn.out_proj.bias grad mean: -0.000284, std: 0.001693
# transformer.encoder.layers.0.linear1.weight grad mean: 0.000000, std: 0.000226
# transformer.encoder.layers.0.linear1.bias grad mean: -0.000005, std: 0.000253
# transformer.encoder.layers.0.linear2.weight grad mean: 0.000000, std: 0.000285
# transformer.encoder.layers.0.linear2.bias grad mean: 0.000001, std: 0.002219
# transformer.encoder.layers.0.norm1.weight grad mean: 0.000019, std: 0.002315
# transformer.encoder.layers.0.norm1.bias grad mean: -0.000047, std: 0.002313
# transformer.encoder.layers.0.norm2.weight grad mean: -0.000038, std: 0.002148
# transformer.encoder.layers.0.norm2.bias grad mean: -0.000038, std: 0.002253
# transformer.encoder.layers.1.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000423
# transformer.encoder.layers.1.self_attn.in_proj_bias grad mean: 0.000010, std: 0.000467
# transformer.encoder.layers.1.self_attn.out_proj.weight grad mean: 0.000014, std: 0.000472
# transformer.encoder.layers.1.self_attn.out_proj.bias grad mean: 0.000153, std: 0.000892
# transformer.encoder.layers.1.linear1.weight grad mean: -0.000000, std: 0.000213
# transformer.encoder.layers.1.linear1.bias grad mean: -0.000011, std: 0.000253
# transformer.encoder.layers.1.linear2.weight grad mean: 0.000000, std: 0.000297
# transformer.encoder.layers.1.linear2.bias grad mean: 0.000002, std: 0.002305
# transformer.encoder.layers.1.norm1.weight grad mean: 0.000007, std: 0.001980
# transformer.encoder.layers.1.norm1.bias grad mean: -0.000001, std: 0.002243
# transformer.encoder.layers.1.norm2.weight grad mean: 0.000007, std: 0.002209
# transformer.encoder.layers.1.norm2.bias grad mean: -0.000370, std: 0.002377
# transformer.encoder.layers.2.self_attn.in_proj_weight grad mean: 0.000000, std: 0.000541
# transformer.encoder.layers.2.self_attn.in_proj_bias grad mean: 0.000087, std: 0.000659
# transformer.encoder.layers.2.self_attn.out_proj.weight grad mean: -0.000006, std: 0.000562
# transformer.encoder.layers.2.self_attn.out_proj.bias grad mean: -0.000063, std: 0.001176
# transformer.encoder.layers.2.linear1.weight grad mean: 0.000000, std: 0.000222
# transformer.encoder.layers.2.linear1.bias grad mean: -0.000002, std: 0.000270
# transformer.encoder.layers.2.linear2.weight grad mean: -0.000001, std: 0.000293
# transformer.encoder.layers.2.linear2.bias grad mean: -0.000008, std: 0.002348
# transformer.encoder.layers.2.norm1.weight grad mean: 0.000017, std: 0.002254
# transformer.encoder.layers.2.norm1.bias grad mean: 0.000016, std: 0.002497
# transformer.encoder.layers.2.norm2.weight grad mean: -0.000002, std: 0.002251
# transformer.encoder.layers.2.norm2.bias grad mean: -0.000100, std: 0.002348
# transformer.encoder.layers.3.self_attn.in_proj_weight grad mean: -0.000000, std: 0.000653
# transformer.encoder.layers.3.self_attn.in_proj_bias grad mean: -0.000028, std: 0.000843
# transformer.encoder.layers.3.self_attn.out_proj.weight grad mean: -0.000038, std: 0.000810
# transformer.encoder.layers.3.self_attn.out_proj.bias grad mean: -0.000217, std: 0.001343
# transformer.encoder.layers.3.linear1.weight grad mean: 0.000000, std: 0.000219
# transformer.encoder.layers.3.linear1.bias grad mean: 0.000004, std: 0.000272
# transformer.encoder.layers.3.linear2.weight grad mean: -0.000001, std: 0.000326
# transformer.encoder.layers.3.linear2.bias grad mean: -0.000008, std: 0.002585
# transformer.encoder.layers.3.norm1.weight grad mean: 0.000037, std: 0.002349
# transformer.encoder.layers.3.norm1.bias grad mean: -0.000146, std: 0.002597
# transformer.encoder.layers.3.norm2.weight grad mean: 0.000052, std: 0.002905
# transformer.encoder.layers.3.norm2.bias grad mean: -0.000044, std: 0.002793
# transformer.encoder.layers.4.self_attn.in_proj_weight grad mean: -0.000000, std: 0.000640
# transformer.encoder.layers.4.self_attn.in_proj_bias grad mean: 0.000164, std: 0.000786
# transformer.encoder.layers.4.self_attn.out_proj.weight grad mean: 0.000000, std: 0.000574
# transformer.encoder.layers.4.self_attn.out_proj.bias grad mean: -0.000383, std: 0.001185
# transformer.encoder.layers.4.linear1.weight grad mean: 0.000000, std: 0.000257
# transformer.encoder.layers.4.linear1.bias grad mean: 0.000003, std: 0.000310
# transformer.encoder.layers.4.linear2.weight grad mean: -0.000001, std: 0.000365
# transformer.encoder.layers.4.linear2.bias grad mean: -0.000011, std: 0.002926
# transformer.encoder.layers.4.norm1.weight grad mean: -0.000075, std: 0.002652
# transformer.encoder.layers.4.norm1.bias grad mean: 0.000024, std: 0.002872
# transformer.encoder.layers.4.norm2.weight grad mean: -0.000007, std: 0.002642
# transformer.encoder.layers.4.norm2.bias grad mean: -0.000137, std: 0.003135
# transformer.encoder.layers.5.self_attn.in_proj_weight grad mean: -0.000000, std: 0.000768
# transformer.encoder.layers.5.self_attn.in_proj_bias grad mean: 0.000095, std: 0.000934
# transformer.encoder.layers.5.self_attn.out_proj.weight grad mean: 0.000011, std: 0.001095
# transformer.encoder.layers.5.self_attn.out_proj.bias grad mean: 0.000264, std: 0.001915
# transformer.encoder.layers.5.linear1.weight grad mean: 0.000000, std: 0.000266
# transformer.encoder.layers.5.linear1.bias grad mean: -0.000010, std: 0.000324
# transformer.encoder.layers.5.linear2.weight grad mean: -0.000002, std: 0.000385
# transformer.encoder.layers.5.linear2.bias grad mean: -0.000021, std: 0.003160
# transformer.encoder.layers.5.norm1.weight grad mean: 0.000084, std: 0.002386
# transformer.encoder.layers.5.norm1.bias grad mean: -0.000056, std: 0.003192
# transformer.encoder.layers.5.norm2.weight grad mean: 0.000000, std: 0.002817
# transformer.encoder.layers.5.norm2.bias grad mean: -0.000000, std: 0.003422
# transformer.encoder.norm.weight grad mean: 0.001109, std: 0.003594
# transformer.encoder.norm.bias grad mean: 0.000100, std: 0.003683
# transformer.decoder.layers.0.self_attn.in_proj_weight grad mean: -0.000002, std: 0.000800
# transformer.decoder.layers.0.self_attn.in_proj_bias grad mean: 0.000110, std: 0.001275
# transformer.decoder.layers.0.self_attn.out_proj.weight grad mean: -0.000009, std: 0.001028
# transformer.decoder.layers.0.self_attn.out_proj.bias grad mean: -0.000375, std: 0.002035
# transformer.decoder.layers.0.multihead_attn.in_proj_weight grad mean: 0.000000, std: 0.001312
# transformer.decoder.layers.0.multihead_attn.in_proj_bias grad mean: -0.000088, std: 0.001637
# transformer.decoder.layers.0.multihead_attn.out_proj.weight grad mean: 0.000026, std: 0.001789
# transformer.decoder.layers.0.multihead_attn.out_proj.bias grad mean: -0.000329, std: 0.003192
# transformer.decoder.layers.0.linear1.weight grad mean: 0.000000, std: 0.000410
# transformer.decoder.layers.0.linear1.bias grad mean: -0.000004, std: 0.000370
# transformer.decoder.layers.0.linear2.weight grad mean: -0.000005, std: 0.000431
# transformer.decoder.layers.0.linear2.bias grad mean: -0.000064, std: 0.002842
# transformer.decoder.layers.0.norm1.weight grad mean: -0.000319, std: 0.003348
# transformer.decoder.layers.0.norm1.bias grad mean: -0.000009, std: 0.002626
# transformer.decoder.layers.0.norm2.weight grad mean: -0.000106, std: 0.003891
# transformer.decoder.layers.0.norm2.bias grad mean: 0.000071, std: 0.002797
# transformer.decoder.layers.0.norm3.weight grad mean: 0.000001, std: 0.003836
# transformer.decoder.layers.0.norm3.bias grad mean: -0.000120, std: 0.002840
# transformer.decoder.layers.1.self_attn.in_proj_weight grad mean: 0.000000, std: 0.001128
# transformer.decoder.layers.1.self_attn.in_proj_bias grad mean: -0.000138, std: 0.001231
# transformer.decoder.layers.1.self_attn.out_proj.weight grad mean: -0.000051, std: 0.001355
# transformer.decoder.layers.1.self_attn.out_proj.bias grad mean: -0.000563, std: 0.001751
# transformer.decoder.layers.1.multihead_attn.in_proj_weight grad mean: -0.000000, std: 0.001135
# transformer.decoder.layers.1.multihead_attn.in_proj_bias grad mean: 0.000080, std: 0.001392
# transformer.decoder.layers.1.multihead_attn.out_proj.weight grad mean: 0.000002, std: 0.001554
# transformer.decoder.layers.1.multihead_attn.out_proj.bias grad mean: -0.000040, std: 0.002465
# transformer.decoder.layers.1.linear1.weight grad mean: 0.000000, std: 0.000394
# transformer.decoder.layers.1.linear1.bias grad mean: -0.000015, std: 0.000340
# transformer.decoder.layers.1.linear2.weight grad mean: -0.000002, std: 0.000431
# transformer.decoder.layers.1.linear2.bias grad mean: -0.000028, std: 0.002585
# transformer.decoder.layers.1.norm1.weight grad mean: -0.000068, std: 0.003043
# transformer.decoder.layers.1.norm1.bias grad mean: 0.000001, std: 0.002228
# transformer.decoder.layers.1.norm2.weight grad mean: -0.000026, std: 0.003804
# transformer.decoder.layers.1.norm2.bias grad mean: -0.000139, std: 0.002641
# transformer.decoder.layers.1.norm3.weight grad mean: 0.000082, std: 0.003786
# transformer.decoder.layers.1.norm3.bias grad mean: 0.000272, std: 0.002770
# transformer.decoder.layers.2.self_attn.in_proj_weight grad mean: -0.000000, std: 0.000960
# transformer.decoder.layers.2.self_attn.in_proj_bias grad mean: 0.000140, std: 0.001093
# transformer.decoder.layers.2.self_attn.out_proj.weight grad mean: 0.000016, std: 0.000825
# transformer.decoder.layers.2.self_attn.out_proj.bias grad mean: 0.000043, std: 0.001731
# transformer.decoder.layers.2.multihead_attn.in_proj_weight grad mean: -0.000000, std: 0.001848
# transformer.decoder.layers.2.multihead_attn.in_proj_bias grad mean: 0.000182, std: 0.002267
# transformer.decoder.layers.2.multihead_attn.out_proj.weight grad mean: -0.000033, std: 0.001967
# transformer.decoder.layers.2.multihead_attn.out_proj.bias grad mean: 0.000375, std: 0.004155
# transformer.decoder.layers.2.linear1.weight grad mean: 0.000000, std: 0.000454
# transformer.decoder.layers.2.linear1.bias grad mean: -0.000005, std: 0.000383
# transformer.decoder.layers.2.linear2.weight grad mean: -0.000004, std: 0.000487
# transformer.decoder.layers.2.linear2.bias grad mean: -0.000054, std: 0.002878
# transformer.decoder.layers.2.norm1.weight grad mean: -0.000047, std: 0.004132
# transformer.decoder.layers.2.norm1.bias grad mean: 0.000013, std: 0.002816
# transformer.decoder.layers.2.norm2.weight grad mean: 0.000013, std: 0.005487
# transformer.decoder.layers.2.norm2.bias grad mean: -0.000088, std: 0.003093
# transformer.decoder.layers.2.norm3.weight grad mean: -0.000006, std: 0.005517
# transformer.decoder.layers.2.norm3.bias grad mean: 0.000083, std: 0.002920
# transformer.decoder.layers.3.self_attn.in_proj_weight grad mean: -0.000000, std: 0.001052
# transformer.decoder.layers.3.self_attn.in_proj_bias grad mean: 0.000085, std: 0.001186
# transformer.decoder.layers.3.self_attn.out_proj.weight grad mean: -0.000011, std: 0.001323
# transformer.decoder.layers.3.self_attn.out_proj.bias grad mean: 0.000089, std: 0.002100
# transformer.decoder.layers.3.multihead_attn.in_proj_weight grad mean: -0.000000, std: 0.001251
# transformer.decoder.layers.3.multihead_attn.in_proj_bias grad mean: 0.000157, std: 0.001545
# transformer.decoder.layers.3.multihead_attn.out_proj.weight grad mean: -0.000004, std: 0.001519
# transformer.decoder.layers.3.multihead_attn.out_proj.bias grad mean: 0.000365, std: 0.002563
# transformer.decoder.layers.3.linear1.weight grad mean: -0.000000, std: 0.000473
# transformer.decoder.layers.3.linear1.bias grad mean: 0.000006, std: 0.000389
# transformer.decoder.layers.3.linear2.weight grad mean: 0.000006, std: 0.000488
# transformer.decoder.layers.3.linear2.bias grad mean: 0.000073, std: 0.002681
# transformer.decoder.layers.3.norm1.weight grad mean: -0.000224, std: 0.004444
# transformer.decoder.layers.3.norm1.bias grad mean: 0.000006, std: 0.002785
# transformer.decoder.layers.3.norm2.weight grad mean: -0.000057, std: 0.004794
# transformer.decoder.layers.3.norm2.bias grad mean: -0.000033, std: 0.002859
# transformer.decoder.layers.3.norm3.weight grad mean: 0.000024, std: 0.005084
# transformer.decoder.layers.3.norm3.bias grad mean: 0.000256, std: 0.002954
# transformer.decoder.layers.4.self_attn.in_proj_weight grad mean: -0.000000, std: 0.001501
# transformer.decoder.layers.4.self_attn.in_proj_bias grad mean: 0.000094, std: 0.001879
# transformer.decoder.layers.4.self_attn.out_proj.weight grad mean: -0.000001, std: 0.001776
# transformer.decoder.layers.4.self_attn.out_proj.bias grad mean: -0.000052, std: 0.002962
# transformer.decoder.layers.4.multihead_attn.in_proj_weight grad mean: -0.000000, std: 0.001114
# transformer.decoder.layers.4.multihead_attn.in_proj_bias grad mean: 0.000297, std: 0.001339
# transformer.decoder.layers.4.multihead_attn.out_proj.weight grad mean: 0.000048, std: 0.001369
# transformer.decoder.layers.4.multihead_attn.out_proj.bias grad mean: 0.000666, std: 0.002189
# transformer.decoder.layers.4.linear1.weight grad mean: 0.000000, std: 0.000539
# transformer.decoder.layers.4.linear1.bias grad mean: 0.000004, std: 0.000413
# transformer.decoder.layers.4.linear2.weight grad mean: -0.000002, std: 0.000538
# transformer.decoder.layers.4.linear2.bias grad mean: -0.000019, std: 0.002369
# transformer.decoder.layers.4.norm1.weight grad mean: -0.000163, std: 0.004115
# transformer.decoder.layers.4.norm1.bias grad mean: 0.000021, std: 0.002230
# transformer.decoder.layers.4.norm2.weight grad mean: -0.000060, std: 0.004076
# transformer.decoder.layers.4.norm2.bias grad mean: 0.000089, std: 0.002448
# transformer.decoder.layers.4.norm3.weight grad mean: 0.000084, std: 0.004002
# transformer.decoder.layers.4.norm3.bias grad mean: -0.000088, std: 0.002592
# transformer.decoder.layers.5.self_attn.in_proj_weight grad mean: 0.000000, std: 0.001434
# transformer.decoder.layers.5.self_attn.in_proj_bias grad mean: 0.000296, std: 0.001611
# transformer.decoder.layers.5.self_attn.out_proj.weight grad mean: 0.000019, std: 0.001556
# transformer.decoder.layers.5.self_attn.out_proj.bias grad mean: 0.000543, std: 0.002754
# transformer.decoder.layers.5.multihead_attn.in_proj_weight grad mean: -0.000000, std: 0.001147
# transformer.decoder.layers.5.multihead_attn.in_proj_bias grad mean: 0.000168, std: 0.001409
# transformer.decoder.layers.5.multihead_attn.out_proj.weight grad mean: 0.000035, std: 0.001757
# transformer.decoder.layers.5.multihead_attn.out_proj.bias grad mean: 0.000481, std: 0.003079
# transformer.decoder.layers.5.linear1.weight grad mean: 0.000000, std: 0.000626
# transformer.decoder.layers.5.linear1.bias grad mean: -0.000020, std: 0.000395
# transformer.decoder.layers.5.linear2.weight grad mean: 0.000009, std: 0.000637
# transformer.decoder.layers.5.linear2.bias grad mean: 0.000105, std: 0.001753
# transformer.decoder.layers.5.norm1.weight grad mean: -0.000496, std: 0.004156
# transformer.decoder.layers.5.norm1.bias grad mean: -0.000013, std: 0.001584
# transformer.decoder.layers.5.norm2.weight grad mean: -0.000020, std: 0.004234
# transformer.decoder.layers.5.norm2.bias grad mean: -0.000090, std: 0.001667
# transformer.decoder.layers.5.norm3.weight grad mean: 0.000001, std: 0.004114
# transformer.decoder.layers.5.norm3.bias grad mean: 0.000000, std: 0.001864
# transformer.decoder.norm.weight grad mean: 0.001035, std: 0.004208
# transformer.decoder.norm.bias grad mean: 0.000371, std: 0.001803
# output_projection.weight grad mean: 0.000005, std: 0.054216
# output_projection.bias grad mean: 0.017598, std: nan
# Epoch 9 training loss: 0.07859661181767781
# Epoch 9 validation loss: 0.6120685935183012
# saved...

# %%
# #save the model
# print("Model's state_dic:")
# for param_tensor in model.state_dic():
#     print(param_tensor, "\t", model.state_dict()[param_tensor].size())

# torch.save(model.state_dict(), 'saved_models/toy_model.pt')

# %%
#test the model
data_folder = 'saved_models/'
model = torch.load(data_folder+'best.model', weights_only=False)
                   
truth_plot_data = torch.empty((0,pred_length,1))       #save data for visualization
pred_plot_data = torch.empty((0,pred_length,1))  #save data for visualization
truth_plot_data = truth_plot_data.to(device=device, dtype=dtype)
pred_plot_data = pred_plot_data.to(device=device, dtype=dtype)

model.eval()
val_loss = 0
counter = 0
for x_batch, y_batch in test_loader:
    x_batch = x_batch.to(device=device, dtype=dtype)
    y_batch = y_batch.to(device=device, dtype=dtype)
    truth_plot_data = torch.cat((truth_plot_data, y_batch))
    with torch.no_grad():
        pred = model(x_batch, y_batch, src_mask=mask, tgt_mask=mask, src_is_causal=True, tgt_is_causal=True)
        #pred = model(x_batch, y_batch)#, src_mask=mask, tgt_mask=mask, src_is_causal=True, tgt_is_causal=True)  #is the the correct place to enter the forward() parameters?
        loss = criterion(pred,y_batch).item()
        pred_plot_data = torch.cat((pred_plot_data, pred))
    val_loss += loss
    counter += 1
val_loss = val_loss/counter
print(f'Test loss: {val_loss}')

truth_plot_data = truth_plot_data.cpu()
pred_plot_data = pred_plot_data.cpu()
# Out:
# Test loss: 0.6120685935183012

# %%
pred_plot_data.shape
pred_plot_data
# Out:
# tensor([[[-0.3400],
#          [-0.3130],
#          [-0.3138],
#          [-0.3466],
#          [-0.3723],
#          [-0.3738]],
#
#         [[-0.3400],
#          [-0.3130],
#          [-0.3138],
#          [-0.3466],
#          [-0.3723],
#          [-0.3738]],
#
#         [[-0.3400],
#          [-0.3130],
#          [-0.3138],
#          [-0.3466],
#          [-0.3723],
#          [-0.3738]],
#
#         ...,
#
#         [[-0.3400],
#          [-0.3130],
#          [-0.3138],
#          [-0.3466],
#          [-0.3723],
#          [-0.3738]],
#
#         [[-0.3400],
#          [-0.3130],
#          [-0.3138],
#          [-0.3466],
#          [-0.3723],
#          [-0.3738]],
#
#         [[-0.3400],
#          [-0.3130],
#          [-0.3138],
#          [-0.3466],
#          [-0.3723],
#          [-0.3738]]])

# %%
#truth_plot_data.shape
x_count = 2
y_count = 2
fig, axs = plt.subplots(x_count, y_count)

count = 0
for a in range(x_count):
    for b in range(y_count):
        axs[a, b].plot(truth_plot_data[count])
        axs[a, b].plot(pred_plot_data[count], 'orange')
        axs[a, b].legend(['Truth', 'Prediction'])
        count = count + 1

# %%
# Plot loss curves
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Train/Test Loss Over Epochs')
plt.show()
